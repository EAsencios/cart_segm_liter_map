# %% [markdown]
# # Loading data into Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
print(df.head(5))

# %% [markdown]
# # Reading Data in Pandas

# %%
## Read Headers

print(df.columns)
